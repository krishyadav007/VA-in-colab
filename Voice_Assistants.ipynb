# %% [markdown]
# <a href="https://colab.research.google.com/github/krishyadav007/VA-in-colab/blob/main/Voice_Assistants.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Voice Assistants

# %% [markdown]
# In this notebook, you will learn how to make your own voice assistant.

# %% [markdown]
# # Importing and installing required libraries

# %%
import pyttsx3 #pyttsx3 is a text-to-speech conversion library in Python.
import webbrowser #It is used to open or close your browser
import random #It is used to obtain a random value from a group of values
import speech_recognition as sr #Main library used to recognize human words
import wikipedia #Used to get articles from wikipedia and summarize them if necessary
import wolframalpha #Used in the core of the VA
import datetime #Used to get the current time
import os #For system related functions
import sys #For system related functions

# %% [markdown]
# # Setting Up The Voice

# %%
engine = pyttsx3.init()
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)

# %% [markdown]
# # Task 1: Change the voice to a female voice

# %%
# Your code here

# %% [markdown]
# # Initiating the voice assistant

# %%
def speak(audio):
    engine.say(audio)
    engine.runAndWait()
def wishMe():
    hour = int(datetime.datetime.now().hour)
    if hour>= 0 and hour<12:
        speak("Good Morning Sir !")
    elif hour>= 12 and hour<18:
        speak("Good Afternoon Sir !")  
    else:
        speak("Good Evening Sir !") 
    name =("Arnold")
    speak("I am your Assistant")
    speak(name)
     
def usrname():
    speak("What should i call you sir")
    uname = takeCommand()
    speak("Welcome")
    speak(uname)
    

    speak("How can i Help you") 
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)
    try:
        print("Recognizing...")   
        query = r.recognize_google(audio, language ='en-in')
        print(f"User said: {query}\n")
    except Exception as e:
        print(e)   
        print("Could you speak more clearly") 
        return "None"
    return query

# %% [markdown]
# # Setting up Main Functions

# %%
if __name__ == '__main__': 
    wishMe()
    usrname() 
    while True:
        query = takeCommand().lower()
        if 'wikipedia' in query:
            speak('Searching Wikipedia...')
            query = query.replace("wikipedia", "")
            results = wikipedia.summary(query, sentences = 3)
            speak("Here is what wikipedia says")
            print(results)
            speak(results)
            
        elif 'open youtube' in query:
            speak("Yes sir")
            webbrowser.open("youtube.com")
            
        elif 'open forum' in query:
            speak("Yes sir")
            webbrowser.open("forum.aistudent.community")
            
        elif 'open google' in query:
            speak("Here you go to Google\n")
            webbrowser.open("Yes sir")
            
        elif 'open stack overflow' in query:
            speak("Yes sir")
            webbrowser.open("stackoverflow.com") 
            
        elif 'play music' in query or "play song" in query:
            speak("Here you go with music")
            music_dir = "Songs"
            songs = os.listdir(music_dir)
            print(songs)  
            random = os.startfile(os.path.join(music_dir, songs[1]))
            
        elif 'how are you' in query:
            speak("I am fine, Thank you")
            speak("How are you, Sir")
            
        elif 'fine' in query or "good" in query:
            speak("It's good to know that your fine")
            
        elif "change name" in query:
            speak("What would you like to call me, Sir ")
            name = takeCommand()
            speak("Thanks for naming me")
            
        elif "what's your name" in query or "What is your name" in query:
            speak("My friends call me")
            name =("Arnold")
            speak(name)
            print("My friends call me", name)
            
        elif 'search' in query or 'play' in query:
            query = query.replace("search", "")
            query = query.replace("play", "")         
            webbrowser.open(query)
            
        elif 'open presentation' in query:
            speak("opening Power Point presentation")
            power = r"D:\Manish\My Journey Through Intel AI For Youth Program.pptx"
            os.startfile(power)
            
        elif "who are you" in query:
            speak("I am your virtual assistant")
            
        elif "where is" in query:
            query = query.replace("where is", "")
            location = query
            speak("User asked to Locate")
            speak(location)
            webbrowser.open("https://www.google.com/maps/search/?api=1&" + location + "")
            
        elif "write a note" in query:
            speak("What should i write, sir")
            note = takeCommand()
            file = open('notes.txt', 'w')
            file.write(note)
            
        elif "show note" in query:
            speak("Showing Notes")
            file = open("notes.txt", "r")
            print(file.read())
            speak(file.read(6))
        elif "will you be my friend" in query:  
            speak("Sure, why not")
        elif 'exit' in query:
            speak("Thanks for giving me your time")
            exit()
# Out:
# Listening...
# Recognizing...
# User said: Arnold
#
# Listening...
# Recognizing...
# User said: name
#
# Listening...
# Recognizing...
# User said: what your name
#
# Listening...
# Recognizing...
# User said: what your name
#
# Listening...
# Recognizing...
# User said: what's your name
#
# My friends call me Arnold
# Listening...
# Recognizing...
# User said: change name
#
# Listening...
# Recognizing...
# User said: wish
#
# Listening...
# Recognizing...
# User said: what is your name
#
# Listening...
# Recognizing...
# User said: what's your name
#
# My friends call me Arnold
# Listening...
# Recognizing...
# User said: open forum
#
# Listening...
# Recognizing...
# User said: play music
#
# ...

# %% [markdown]
# # Task 2: Add more functions

# %%
# Your code here

# %% [markdown]
# # Thank You
